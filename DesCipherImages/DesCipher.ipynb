# %%
import base64 as bs
# !pip install pyDes
from pyDes import *
# Out:
# Requirement already satisfied: pyDes in /usr/local/lib/python3.7/dist-packages (2.0.1)

# %%
import pyDes as ds

# %%
def guardar(nombreArchivo,data):
	f = open(nombreArchivo, 'wb')
	f.write(data)
	f.close()
	
def encryptDES(plaintext):
	BLOCK_SIZE = 8
	padding = b"@"
	plaintext = plaintext + ((BLOCK_SIZE - len(plaintext)) % BLOCK_SIZE) * padding
	cipherkey = ds.des(b"DESCRYPT", ds.CBC, b"\0\0\0\0\0\0\0\0", pad=None, padmode=ds.PAD_PKCS5)
	ciphertext = cipherkey.encrypt(plaintext)
	print("Imagen Encriptada\n")
	return ciphertext

def decryptDES(mensaje):
	cipherkey = ds.des(b"DESCRYPT", ds.CBC, b"\0\0\0\0\0\0\0\0", pad=None, padmode=ds.PAD_PKCS5)
	plaintext = cipherkey.decrypt(mensaje)
	print("Imagen Desencriptada\n")
	return plaintext

if __name__=="__main__":	
  print('''Des Cipher Images\nElige una de estas dos opciones:\n
        \t1) Cifrar una imagen.
        \t2) Descifrar una imagen.
        ''')
  opc = int(input("opcion >"))
  if opc == 1:
    print("Procesando imagen con pyDes espere...")
    ruta = "sample_data/original.png"
    fp = open(ruta, 'rb')
    text  = fp.read()
    fp.close()
    e_text = encryptDES(text)
    eBase64 = bs.b64encode(e_text)
    print ("mensaje cifrado en Base64: ", eBase64 )
    guardar("imagenEncriptada.png",eBase64)
  else:
    print("Procesando imagen con pyDes espere...")   
    ruta = "imagenEncriptada.png"
    fp = open(ruta, 'rb')
    text  = fp.read()
    fp.close()
    dBase64 = bs.b64decode(text)
    d_text = decryptDES(dBase64)
    print ("mensaje descifrado en bits: ", dBase64)
    guardar("imagenDesencriptada.png",d_text)
# Out:
# Des Cipher Images
# Elige una de estas dos opciones:
#
#         	1) Cifrar una imagen.
#         	2) Descifrar una imagen.
#
# opcion >2
# Procesando imagen con pyDes espere...
# Imagen Desencriptada
#
# mensaje descifrado en bits:  b'\xe2\x86\xcd\x12\xcf\xd6C\xb4Y\xf5\xbc\x06\xb5\xaf\x11\xf4\x10PPhMp\x08a\x942\x01uF,\xa7\x04\xacCH\xce\x85\xd1\x0b\xa1\xc8&\xec\xcaa\xd2\x9f\x90\xe0KT\x95\xb7`v\xce&\xab\x066\xc0v\x1eF\xfb\x8c\x06\x88\xec\x05Y\x16\xdc\xd9=\x1f\xa7\xff\x07\xfcY\xaa\x14\xe8\xa5\xd5\xd3\xc1U\xca\xc8\xc39|\xa8\x9aJ\xd7\xe3~u;\x9a(\xbf\xe42\xa5\xeb\x00\x10\xbel\x1a\xac\x1f\x9f\xaa8c\xc9_Cu\xd1\x10\xe9FtAv\x03\xa5&!\xd5\x15\xd1\xd5\xe4\xb9\x04\xfa\x85rB7\x1df\xabq\xf4\xff\xacO}\x1c\xd5\xa6\x98C\xe3\x18ft5y\xa7m\xe7\x85\xb1m\xa5Uq\xd4z\xe1\xbb\x07\x1c\xd3\xdf\x11\x91\x01\xe9\x9d W\xb3\xda\xe7\xe6,g?\xc1\x96 \x87q$\xbcP\xd